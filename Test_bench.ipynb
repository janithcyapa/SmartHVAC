# %% [markdown]
# <a href="https://colab.research.google.com/github/janithcyapa/SmartHVAC/blob/main/Test_bench.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Smart HVAC

# %% [markdown]
# ### Model sketch

# %% [markdown]
# ![Blank diagram.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# https://lucid.app/lucidchart/b6dc8846-6534-4520-8778-57e19c14b191/edit?viewport_loc=-314%2C-11%2C2253%2C1010%2C0_0&invitationId=inv_4412edbf-0bcb-4820-9819-718b5bdaadc5

# %% [markdown]
# ### Calculations

# %% [markdown]
# Controlling room volume = $1 feet^2$ \
# Heating capasity of Heat Load = $60W$ \
# Expected minimum temperature of room = $25 ^o C$
